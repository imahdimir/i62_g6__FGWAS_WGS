# %%
# !ibd.py --bed ukb22418_c22_b0_v2 --king array_data__kinship_degree1.kin0 --agesex agesex.txt --out array_data_chr_22 --threads 4 --ld_out --p_error 0.0001 --chrom 22

# %%
ls
# Out:
# agesex.txt                                ukb22418_c22_b0_v2.fam
# array_data__kinship_degree1.kin0          ukb24309_c22_b0_v1.bgen
# array_data_chr_22_chr_22.ibd.segments.gz  ukb24309_c22_b0_v1.sample
# array_data_chr_22_chr_22.l2.ldscore.gz    wgs_chr22_filtered-temporary.pgen
# c22.txt                                   wgs_chr22_filtered-temporary.psam
# ukb22418_c22_b0_v2.bed                    wgs_chr22_filtered-temporary.pvar
# ukb22418_c22_b0_v2.bim                    wgs_chr22_filtered.log

# %%
# !dx upload array_data_chr_22_chr_22*
# Out:
# [===========================================================>] Uploaded 1,790,619 of 1,790,619 bytes (100%) array_data_chr_22_chr_22.ibd.segments.gz
# ID                                file-J1yqpjQJQp6xvxbjjGX6JK74
# Class                             file
# Project                           project-J1VzYJQJQp6z67g2f0Vvb2kK
# Folder                            /
# Name                              array_data_chr_22_chr_22.ibd.segments.gz
# State                             closing
# Visibility                        visible
# Types                             -
# Properties                        -
# Tags                              -
# Outgoing links                    -
# Created                           Mon Jul 21 04:09:06 2025
# Created by                        mahdimir
#  via the job                      job-J1ygYzjJQp6VGFJ73Z3P9880
# Last modified                     Mon Jul 21 04:09:07 2025
# Media type
# archivalState                     "live"
# ...
