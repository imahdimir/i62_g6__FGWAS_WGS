# %%
# check whether the filtered bgen file is phased?
from bgen_reader import open_bgen

# %%
# !ls
# Out:
# agesex.txt		 ukb24309_c22_b0_v1.bgen.bgi
# c22.txt			 ukb24309_c22_b0_v1.sample
# chr22_variants.txt	 wgs_chr22_filtered_2k.bgen
# chr22_variants_2k.txt	 wgs_chr22_filtered_2k.bgen.metadata2.mmm
# ukb24309_c22_b0_v1.bgen

# %%
bgen = open_bgen("wgs_chr22_filtered_2k.bgen")
# Out:
# metadata -- time=0:00:00.02, 'ids': part 15 of 15
# metadata -- time=0:00:00.43, 'generate samples': part 490,541 of 490,541
# metadata -- time=0:00:00.27, 'sample range': part 490,541 of 490,541

# %%
print(bgen.phased)  # This prints True if data is phased, False if unphased
# Out:
# [False False False ... False False False]

# %%
len(bgen.phased)
# Out:
# 2000
